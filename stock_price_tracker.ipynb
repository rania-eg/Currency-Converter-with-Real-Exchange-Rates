# %% [markdown]
# <a href="https://colab.research.google.com/github/rania-eg/Currency-Converter-with-Real-Exchange-Rates/blob/main/stock_price_tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
import pandas as pd

# %%
symbol = input("Enter stock symbol (e.g. AAPL, TSLA, GOOG): ").upper()
# Out:
# Enter stock symbol (e.g. AAPL, TSLA, GOOG): AAPL

# %%
data=yf.download(symbol, period="7d", interval="1d")
# Out:
# /tmp/ipython-input-2744909061.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data=yf.download(symbol, period="7d", interval="1d")
# [*********************100%***********************]  1 of 1 completed

# %%
data["Daily Change (%)"] = data["Close"].pct_change() * 100

# %%
latest = data.tail(1)
print("\n📊 Latest Stock Data:\n")
print(latest[["Close", "Daily Change (%)"]])
# Out:
# 📊 Latest Stock Data:
#
# Price            Close Daily Change (%)
# Ticker            AAPL
# Date
# 2025-10-21  262.769989         0.202104

# %%
data["Close"].plot(title=f"{symbol} Stock Price (Last 7 Days)", ylabel="Price ($)", grid=True)
# Out:
# <Axes: title={'center': 'AAPL Stock Price (Last 7 Days)'}, xlabel='Date', ylabel='Price ($)'>
